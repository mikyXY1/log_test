# %% [markdown]
# Jupyter Notebook

# %%
msg1 = "Hello, World!"
print(msg1)

# %% [markdown]
# Toto je další zpráva

# %%
msg2 = "Hello, Earth!"
print(msg2)

# %% [markdown]
# **Zobrazení zprávy pomocí Bash příkazu:**

# %%
# !echo "Message from Bash Shell!"
# Out:
# Message from Bash Shell!
